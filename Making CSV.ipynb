# %%
import pandas as pd
import os
import json

# %%
df_l = []

# %%
for file_name in os.listdir('./processed_data/matches/'):
    with open(os.path.join('./processed_data/matches/', file_name)) as f:
        s = json.load(f)
        df_l.append(s)

# %%
df = pd.DataFrame.from_records(df_l)

# %%
df
# Out:
#              city        date dl_applied      eliminator       id  overs  \
# 0          Mumbai  2010-04-24                              419164     20
# 1           Delhi  2010-03-29                              419131     20
# 2          Mumbai  2008-05-16                              336021     20
# 3            Pune  2016-04-22                              980931     20
# 4          Mumbai  2010-04-22                              419163     20
# 5      Chandigarh  2010-04-02                              419136     20
# 6       Bangalore  2008-05-19                              336026     20
# 7         Kolkata  2016-05-04                              980963     20
# 8         Chennai  2011-05-01                              501236     20
# 9          Mumbai  2011-05-20                              501263     20
# 10         Mumbai  2014-05-30                              734047     20
# 11     Chandigarh  2008-04-19                              335983     20
# ...

# %%
df.to_csv('matches.csv', index=False)

# %%
df_i = []

# %%
for file_name in os.listdir('./processed_data/innings/'):
    with open(os.path.join('./processed_data/innings/', file_name)) as f:
        print(file_name)
        s = json.load(f)
        df_i.append(s)
# Out:
# 1178400_1st_inn.json
# 548315_1st_inn.json
# 598064_2nd_inn.json
# 598031_2nd_inn.json
# 829749_2nd_inn.json
# 335988_1st_inn.json
# 734019_1st_inn.json
# 548357_2nd_inn.json
# 1178417_2nd_inn.json
# 501268_1st_inn.json
# 598026_1st_inn.json
# 598073_1st_inn.json
# 1178399_2nd_inn.json
# 548347_1st_inn.json
# 548312_1st_inn.json
# 734009_2nd_inn.json
# 1178407_1st_inn.json
# 598063_2nd_inn.json
# 598036_2nd_inn.json
# 1082648_1st_inn.json
# 1136620_2nd_inn.json
# 1178410_2nd_inn.json
# 548350_2nd_inn.json
# 598021_1st_inn.json
# 829759_1st_inn.json
# 335998_2nd_inn.json
# 392231_1st_inn.json
# 980987_2nd_inn.json
# 392226_2nd_inn.json
# 980997_1st_inn.json
# 392236_1st_inn.json
# 392221_2nd_inn.json
# 1178405_2nd_inn.json
# 548310_2nd_inn.json
# 548345_2nd_inn.json
# 598034_1st_inn.json
# 598061_1st_inn.json
# 829719_1st_inn.json
# 1082608_1st_inn.json
# 734049_2nd_inn.json
# 548352_1st_inn.json
# 548307_1st_inn.json
# 1178412_1st_inn.json
# 501238_2nd_inn.json
# 598023_2nd_inn.json
# ...

# %%
df_i = pd.DataFrame.from_records(df_i)

# %%
df_i
